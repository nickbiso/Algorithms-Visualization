# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %%
class random_nos:
    def __init__(self,size,min_num = 5,max_num = 1000):
        self.rand_list = random.sample(range(min_num,max_num), size)
        self.i = 0
        self.max_num = max_num
        self.size = size
        self.frames = []
        self.colors = []
        self.index = np.arange(size) 
        self.length = len(self.rand_list)
        self.base_colors = ['gray']*self.length
        
    def generate(self):
        self.rand_list = random.sample(range(min_num,self.max_num), self.size)
        return self.rand_list
        
    def visualize(self):
        color = ['gray']*length
        fig = plt.figure()
        plt.bar(index, self.rand_list,color=color)
        plt.xticks(index)
        #plt.Figure(figsize=(10,10))
        plt.show()
        

    
    def save_video(self):
        fig = plt.figure(figsize=(8, 4))
        plt.xticks(self.index)
        rects = plt.bar(self.index, self.frames[0],color=self.colors[0])
        
        def animate(i):
            #for rect, yi,c,t in zip(rects, data[i],colors[i],titles[i]):
            for rect, yi,c in zip(rects, self.frames[i],self.colors[i]):
            #for rect, yi in zip(rects, data[i]):
                rect.set_height(yi)
                rect.set_color(c)
                #ttl.set_text(t)
                #plt.draw()

            return rects

        
        anim = animation.FuncAnimation(fig, animate, frames=len(x.frames), interval=50)
        anim.save('bar.mp4', writer='pillow')#, dpi = 100)
    
    def plot(self):
        HTML("""<video alt="test" controls>
        <source src="bar.mp4" type="video/mp4">
    </video>""")
        
    def bubble_sort(self):
        self.frames.append(self.rand_list.copy())
        self.colors.append(self.base_colors.copy())

        for i in range(0,self.length):
            for j in range(0,self.length-1-i):

                if self.rand_list[j]>self.rand_list[j+1]:

                    swap = self.rand_list[j+1]
                    self.rand_list[j+1] = self.rand_list[j]
                    self.rand_list[j] = swap

                    colors_iter = self.base_colors.copy()
                    colors_iter[j] = 'red'
                    colors_iter[j+1] = 'red'
                    self.colors.append(colors_iter.copy())

                else:
                    colors_iter = self.base_colors.copy()
                    colors_iter[j] = 'green'
                    colors_iter[j+1] = 'green'
                    self.colors.append(colors_iter.copy())

                self.frames.append(self.rand_list.copy())

# %%
test = random_nos(25)

# %%
test.visualize()

# %%
x = random_nos(15)

# %%
x.rand_list
# Out:
# [928, 671, 918, 405, 165, 163, 552, 39, 387, 354, 957, 207, 851, 728, 450]

# %%
x.bubble_sort()

# %%
x.rand_list
# Out:
# [39, 163, 165, 207, 354, 387, 405, 450, 552, 671, 728, 851, 918, 928, 957]

# %%
x.frames
# Out:
# [[928, 671, 918, 405, 165, 163, 552, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 928, 918, 405, 165, 163, 552, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 928, 405, 165, 163, 552, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 928, 165, 163, 552, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 928, 163, 552, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 928, 552, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 552, 928, 39, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 552, 39, 928, 387, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 552, 39, 387, 928, 354, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 552, 39, 387, 354, 928, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 552, 39, 387, 354, 928, 957, 207, 851, 728, 450],
#  [671, 918, 405, 165, 163, 552, 39, 387, 354, 928, 207, 957, 851, 728, 450],
# ...

# %%
x.colors
# Out:
# [['gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray'],
#  ['red',
#   'red',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray'],
#  ['gray',
#   'red',
#   'red',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray'],
#  ['gray',
#   'gray',
#   'red',
#   'red',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray'],
#  ['gray',
#   'gray',
#   'gray',
#   'red',
#   'red',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray',
#   'gray'],
#  ['gray',
#   'gray',
#   'gray',
#   'gray',
#   'red',
#   'red',
#   'gray',
#   'gray',
# ...

# %%
x.save_video()
# Out:
# C:\Users\nickj\AppData\Local\Continuum\Anaconda3\envs\py35\lib\site-packages\matplotlib\animation.py:1021: UserWarning: MovieWriter pillow unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)

# %%
HTML("""<video alt="test" controls>
        <source src="bar.mp4" type="video/mp4">
    </video>""")
# Out:
# <video alt="test" controls>
#         <source src="bar.mp4" type="video/mp4">
#     </video>
